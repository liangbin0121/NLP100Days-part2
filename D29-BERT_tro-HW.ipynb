# %% [markdown]
# # 作業 : 調整 Bert 模型的不同訓練參數

# %% [markdown]
# # [作業目標]
# - 調整 Bert 模型的不同參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [作業重點]
# - 調整 Bert 模型的不同訓練參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [參數說明]
# - MODEL_DIM : Attention 特徵維度，即每一筆訓練輸入單字的個數
# - N_LAYER : Attention 堆疊的層數
# - LEARNING_RATE : 學習速率，影響收斂的快慢
# - MASK_RATE : 掩碼比例(介於 0 到 0.5 間, 建議值 0.15)

# %% [markdown]
# # 程式說明
# - 程式採用 tensorflow2 / keras 寫作, 執行前請先安裝 tensorflow 2.0
# - 本程式執行時, 請將 utils.py / transformer.py / GPT.py 等三個檔案與執行檔放置於同一目錄下
# - 程式來源 : 莫煩Python-BERT:雙向語言模型 https://mofanpy.com/tutorials/machine-learning/nlp/bert/

# %%
# 連接個人資料 讀取 ＰＴＴ 訓練資料和儲存模型
#先連接自己的GOOGLE DRIVE 為了要儲存資料和訓練模型
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Current directory
print(os.getcwd())

# change directory D29_BERT_intro
os.chdir('/content/drive/MyDrive/python_training/NLP100Days-part2/D29_BERT_intro/')
print(os.getcwd())
# Out:
# /content
# /content/drive/MyDrive/python_training/NLP100Days-part2/D29_BERT_intro

# %%
# [BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding](https://arxiv.org/pdf/1810.04805.pdf)
import numpy as np
import tensorflow as tf
import utils    # this refers to utils.py in my [repo](https://github.com/MorvanZhou/NLP-Tutorials/)
import time
from GPT import GPT
import os
import pickle


class BERT(GPT):
    def __init__(self, model_dim, max_len, n_layer, n_head, n_vocab, lr, max_seg=3, drop_rate=0.1, padding_idx=0):
        super().__init__(model_dim, max_len, n_layer, n_head, n_vocab, lr, max_seg, drop_rate, padding_idx)
        # I think task emb is not necessary for pretraining,
        # because the aim of all tasks is to train a universal sentence embedding
        # the body encoder is the same across all tasks,
        # and different output layer defines different task just like transfer learning.
        # finetuning replaces output layer and leaves the body encoder unchanged.

        # self.task_emb = keras.layers.Embedding(
        #     input_dim=n_task, output_dim=model_dim,  # [n_task, dim]
        #     embeddings_initializer=tf.initializers.RandomNormal(0., 0.01),
        # )

    def step(self, seqs, segs, seqs_, loss_mask, nsp_labels):
        with tf.GradientTape() as tape:
            mlm_logits, nsp_logits = self.call(seqs, segs, training=True)
            mlm_loss_batch = tf.boolean_mask(self.cross_entropy(seqs_, mlm_logits), loss_mask)
            mlm_loss = tf.reduce_mean(mlm_loss_batch)
            nsp_loss = tf.reduce_mean(self.cross_entropy(nsp_labels, nsp_logits))
            loss = mlm_loss + 0.2 * nsp_loss
            grads = tape.gradient(loss, self.trainable_variables)
            self.opt.apply_gradients(zip(grads, self.trainable_variables))
        return loss, mlm_logits

    def mask(self, seqs):
        mask = tf.cast(tf.math.equal(seqs, self.padding_idx), tf.float32)
        return mask[:, tf.newaxis, tf.newaxis, :]  # [n, 1, 1, step]


def _get_loss_mask(len_arange, seq, pad_id):
    rand_id = np.random.choice(len_arange, size=max(2, int(MASK_RATE * len(len_arange))), replace=False)
    loss_mask = np.full_like(seq, pad_id, dtype=np.bool)
    loss_mask[rand_id] = True
    return loss_mask[None, :], rand_id


def do_mask(seq, len_arange, pad_id, mask_id):
    loss_mask, rand_id = _get_loss_mask(len_arange, seq, pad_id)
    seq[rand_id] = mask_id
    return loss_mask


def do_replace(seq, len_arange, pad_id, word_ids):
    loss_mask, rand_id = _get_loss_mask(len_arange, seq, pad_id)
    seq[rand_id] = np.random.choice(word_ids, size=len(rand_id))
    return loss_mask


def do_nothing(seq, len_arange, pad_id):
    loss_mask, _ = _get_loss_mask(len_arange, seq, pad_id)
    return loss_mask


def random_mask_or_replace(data, arange, batch_size):
    seqs, segs, xlen, nsp_labels = data.sample(batch_size)
    seqs_ = seqs.copy()
    p = np.random.random()
    if p < 0.7:
        # mask
        loss_mask = np.concatenate(
            [do_mask(
                seqs[i],
                np.concatenate((arange[:xlen[i, 0]], arange[xlen[i, 0] + 1:xlen[i].sum() + 1])),
                data.pad_id,
                data.v2i["<MASK>"]) for i in range(len(seqs))], axis=0)
    elif p < 0.85:
        # do nothing
        loss_mask = np.concatenate(
            [do_nothing(
                seqs[i],
                np.concatenate((arange[:xlen[i, 0]], arange[xlen[i, 0] + 1:xlen[i].sum() + 1])),
                data.pad_id) for i in range(len(seqs))], axis=0)
    else:
        # replace
        loss_mask = np.concatenate(
            [do_replace(
                seqs[i],
                np.concatenate((arange[:xlen[i, 0]], arange[xlen[i, 0] + 1:xlen[i].sum() + 1])),
                data.pad_id,
                data.word_ids) for i in range(len(seqs))], axis=0)
    return seqs, segs, seqs_, loss_mask, xlen, nsp_labels


def train(model, data, step=10000, name="bert"):
    t0 = time.time()
    arange = np.arange(0, data.max_len)
    for t in range(step):
        seqs, segs, seqs_, loss_mask, xlen, nsp_labels = random_mask_or_replace(data, arange, 16)
        loss, pred = model.step(seqs, segs, seqs_, loss_mask, nsp_labels)
        if t % 100 == 0:
            pred = pred[0].numpy().argmax(axis=1)
            t1 = time.time()
            print(
                "\n\nstep: ", t,
                "| time: %.2f" % (t1 - t0),
                "| loss: %.3f" % loss.numpy(),
                "\n| tgt: ", " ".join([data.i2v[i] for i in seqs[0][:xlen[0].sum()+1]]),
                "\n| prd: ", " ".join([data.i2v[i] for i in pred[:xlen[0].sum()+1]]),
                "\n| tgt word: ", [data.i2v[i] for i in seqs_[0]*loss_mask[0] if i != data.v2i["<PAD>"]],
                "\n| prd word: ", [data.i2v[i] for i in pred*loss_mask[0] if i != data.v2i["<PAD>"]],
                )
            t0 = t1
    os.makedirs("./visual/models/%s" % name, exist_ok=True)
    model.save_weights("./visual/models/%s/model.ckpt" % name)


def export_attention(model, data, name="bert"):
    model.load_weights("./visual/models/%s/model.ckpt" % name)

    # save attention matrix for visualization
    seqs, segs, xlen, nsp_labels = data.sample(32)
    model.call(seqs, segs, False)
    data = {"src": [[data.i2v[i] for i in seqs[j]] for j in range(len(seqs))], "attentions": model.attentions}
    path = "./visual/tmp/%s_attention_matrix.pkl" % name
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, "wb") as f:
        pickle.dump(data, f)


if __name__ == "__main__":
    utils.set_soft_gpu(True)
    MODEL_DIM = 512 #256
    N_LAYER = 4
    LEARNING_RATE = 1e-4
    MASK_RATE = 0.3 #0.15

    d = utils.MRPCData("./MRPC", 2000)
    print("num word: ", d.num_word)
    m = BERT(
        model_dim=MODEL_DIM, max_len=d.max_len, n_layer=N_LAYER, n_head=4, n_vocab=d.num_word,
        lr=LEARNING_RATE, max_seg=d.num_seg, drop_rate=0.2, padding_idx=d.v2i["<PAD>"])
    train(m, d, step=10000, name="bert")
    export_attention(m, d, "bert")
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# num word:  12880
#
#
# step:  0 | time: 5.87 | loss: 9.641
# | tgt:  <GO> hundreds of reporters and photographers swamped the courthouse <MASK> <MASK> the hearing <MASK> <MASK> was carried live on <MASK> cable networks . <SEP> hundreds of reporters <MASK> <MASK> <MASK> <MASK> town <MASK> the <MASK> hearing involving the five-time <MASK> was carried live on <MASK> cable networks
# | prd:  ophir sunnis murrah sunnis elf smooth sisters -ton sunnis davidowitz contested sunnis arab foreign-exchange grave sunnis sunnis licence contested elf murrah elf elf elf elf sunnis medicaid intensities elf distributed intensities elusive caufield licence ships--about xl davidowitz licence sisters elf .rlx broadside ships--about sunnis davidowitz sunnis elf
# | tgt word:  ['grounds', 'before', ',', 'which', 'national', 'and', 'photographers', 'swamped', 'the', 'and', 'short', 'all-star', 'national']
# | prd word:  ['davidowitz', 'contested', 'foreign-exchange', 'grave', 'elf', 'intensities', 'elf', 'distributed', 'intensities', 'caufield', 'ships--about', 'elf', 'davidowitz']
#
#
# step:  100 | time: 20.73 | loss: 7.155
# | tgt:  <GO> a rival distributor <MASK> mike <MASK> from united international <MASK> , <MASK> <MASK> unlike the matrix revolutions , he cannot detect any <MASK> scepticism <MASK> even within <MASK> business . <SEP> a rival <MASK> <MASK> mike <MASK> <MASK> of united international pictures , says <MASK> <MASK> detect <MASK> unlike the matrix revolutions , any <MASK> scepticism
# | prd:  the , the , the the the , the , , , the the the , , , , , , the the , the the the the the , the , the the the the the the the , the the the , , , the the , the , , , , , the the
# | tgt word:  [',', 'selwyn', 'pictures', 'says', 'that', 'advance', ',', 'the', 'distributor', ',', 'selwyn', ',', 'he', 'cannot', ',', 'advance']
# | prd word:  ['the', 'the', ',', 'the', 'the', ',', 'the', 'the', 'the', 'the', 'the', 'the', ',', 'the', ',', 'the']
#
#
# step:  200 | time: 20.55 | loss: 6.767
# | tgt:  <GO> <MASK> in <MASK> <MASK> accounted for <MASK> percent <MASK> the number of traffic deaths in <NUM> , the agency says . <SEP> fatalities in rollover <MASK> accounted for <NUM> <MASK> <MASK> <MASK> increase in <MASK> <MASK> nhtsa said
# | prd:  <GO> , , , <NUM> , , , , , , , <NUM> , , , <NUM> , , , , <NUM> , , , , <NUM> , , <NUM> <NUM> , <NUM> , <NUM> , , , ,
# | tgt word:  ['deaths', 'rollover', 'crashes', '<NUM>', 'of', 'crashes', 'percent', 'of', 'the', '<NUM>', ',']
# | prd word:  [',', ',', '<NUM>', ',', ',', '<NUM>', '<NUM>', ',', '<NUM>', ',', ',']
#
#
# step:  300 | time: 20.54 | loss: 6.803
# | tgt:  <GO> responding , <MASK> skyler , a spokesman for the mayor , said <MASK> <MASK> <MASK> the comptroller 's statements , while <MASK> for their <MASK> <MASK> <MASK> <MASK> relation to <MASK> facts . <SEP> jordan barowitz <MASK> a <MASK> <MASK> republican mayor michael bloomberg said : <quote> the <MASK> <MASK> statements , <MASK> noteworthy for their <MASK> <MASK> bear <MASK> relation to the facts .
# | prd:  <GO> the , , , , , , , the , , , , , , the , , <SEP> , <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <GO> <SEP> <SEP> , , the , the , , , , , , , , the , , the , the the the the , the the , , , the , ,
# | tgt word:  ['edward', 'later', ':', '<quote>', 'noteworthy', 'sensationalism', ',', 'bear', 'no', 'the', ',', 'spokesman', 'for', 'comptroller', "'s", 'while', 'sensationalism', ',', 'no']
# | prd word:  [',', ',', ',', ',', '<SEP>', '<SEP>', '<SEP>', '<SEP>', '<SEP>', '<SEP>', 'the', 'the', ',', ',', ',', 'the', ',', 'the', ',']
#
#
# step:  400 | time: 20.54 | loss: 7.081
# | tgt:  <GO> this <MASK> with <MASK> purifyplus and allows developers <MASK> <MASK> in <MASK> <MASK> of java <MASK> <MASK> c # and <MASK> basic .net. <MASK> ibm said <MASK> rational <MASK> <MASK> also integrated with rational purifyplus , which allows developers to work in java , visual c <MASK> and visualbasic
# | prd:  <GO> the , , , , and , , the , in , , of , the , <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> the the the , , the , , , , , , , , , , , in , , , , , and ,
# | tgt word:  ['integrates', 'rational', 'to', 'work', 'supported', 'versions', ',', 'visual', 'visual', '<SEP>', 'the', 'products', 'were', '#']
# | prd word:  [',', ',', 'the', ',', ',', ',', 'the', ',', '<SEP>', '<SEP>', 'the', ',', 'the', ',']
#
#
# step:  500 | time: 20.71 | loss: 6.246
# | tgt:  <MASK> <MASK> years ago , they were married by a justice <MASK> the peace . <SEP> his wife , <MASK> to moore by <MASK> justice <MASK> the <MASK> , started <MASK> her dream <MASK>
# | prd:  <GO> the <GO> , , <GO> <GO> to <GO> <GO> to , the <GO> <SEP> <SEP> the the , the to to <GO> the to to the the , , the to to ,
# | tgt word:  ['<GO>', 'nine', 'of', 'married', 'a', 'of', 'peace', 'planning', 'wedding']
# | prd word:  ['<GO>', 'the', ',', 'the', 'the', 'to', 'the', 'the', ',']
#
#
# step:  600 | time: 20.65 | loss: 6.138
# | tgt:  <MASK> <MASK> year or two later , <NUM> <MASK> or <MASK> per cent , of the <MASK> reported that they had started to smoke , or <MASK> taken just a <MASK> <MASK> . <MASK> within two years <MASK> <NUM> , or <NUM> <MASK> , of <MASK> youths reported <MASK> had <MASK> <MASK> <MASK> or had at least <MASK> a <MASK> puffs
# | prd:  <GO> the , , , , , <NUM> , , <NUM> , , , of the <NUM> , <SEP> the , , to , , , <NUM> <SEP> <SEP> a <SEP> <SEP> <SEP> <SEP> , <NUM> <NUM> , <NUM> , , <NUM> , , of <NUM> <NUM> , <NUM> <GO> , <NUM> <NUM> , the at <NUM> <NUM> a <NUM> <GO>
# | tgt word:  ['<GO>', 'a', ',', '<NUM>', 'youths', 'had', 'few', 'puffs', '<SEP>', ',', 'percent', 'the', 'they', 'started', 'to', 'smoke', 'taken', 'few']
# | prd word:  ['<GO>', 'the', ',', '<NUM>', '<NUM>', '<NUM>', '<SEP>', '<SEP>', '<SEP>', ',', ',', '<NUM>', '<NUM>', ',', '<NUM>', '<NUM>', '<NUM>', '<NUM>']
#
#
# step:  700 | time: 20.54 | loss: 6.370
# | tgt:  <GO> seniors would then have to pay <NUM> percent of sister-in-law drug relief freitas ibm $ <NUM> . model above that , medicare slowed cognitive <NUM> negotiations of all insurance costs
# | prd:  <GO> the to the <SEP> to to <NUM> <NUM> of <NUM> <NUM> <NUM> <NUM> to <NUM> <NUM> <SEP> <SEP> the to , the <NUM> <NUM> <NUM> <NUM> of the <NUM> <NUM>
# | tgt word:  ['their', 'costs', 'up', 'to', '<SEP>', 'would', 'pay', 'percent', 'drug']
# | prd word:  ['<NUM>', '<NUM>', '<NUM>', 'to', '<SEP>', '<NUM>', '<NUM>', '<NUM>', '<NUM>']
#
#
# step:  800 | time: 20.48 | loss: 5.903
# | tgt:  <GO> roberson was bitten on <MASK> back and scratched on <MASK> leg , according to <MASK> mother <MASK> shamika woumnm of dorchester . <SEP> <MASK> <MASK> <MASK> <MASK> <MASK> back and <MASK> on the leg , her mother <MASK>
# | prd:  <GO> the was , on , the and , on , , , the to , <SEP> and , the of said <SEP> <SEP> , , the the the the and , on the , , , the to
# | tgt word:  ['the', 'the', 'her', ',', 'she', 'was', 'bitten', 'on', 'the', 'scratched', 'said']
# | prd word:  [',', ',', ',', 'and', ',', ',', 'the', 'the', 'the', ',', 'to']
#
#
# step:  900 | time: 20.65 | loss: 6.083
# | tgt:  <MASK> but <MASK> the end <MASK> all <MASK> <MASK> did was visit a pornography site , said vincent weafer , a <MASK> director with <MASK> security response <MASK> <MASK> . <MASK> <MASK> vincent weafer , <MASK> director with symantec security <MASK> , said all <MASK> virus did was visit <MASK> pornography site
# | prd:  <GO> <quote> said the , , the , , , was , a , , , said , , , a , , with , , , said <SEP> <SEP> <SEP> , , , , , , with a , , , said , , said , was , , , ,
# | tgt word:  ['<GO>', 'in', ',', 'the', 'worm', 'security', 'symantec', 'in', 'california', '<SEP>', 'but', 'security', 'response', 'the', 'a']
# | prd word:  ['<GO>', 'said', ',', ',', ',', ',', ',', 'said', '<SEP>', '<SEP>', ',', ',', ',', ',', ',']
#
#
# step:  1000 | time: 20.50 | loss: 5.806
# | tgt:  <MASK> <MASK> <MASK> faces significant regulatory delays and <MASK> , <MASK> <MASK> serious <MASK> <MASK> <MASK> company 's <MASK> , he added . <SEP> <quote> it is highly conditional , faces significant regulatory delays and <MASK> <MASK> and threatens serious damage <MASK> our business .
# | prd:  <GO> <quote> the said and to in and the , , the said to to to in 's <quote> , he said <SEP> <SEP> <quote> it is <quote> <quote> , said said to to and to the and and said and to <quote> said .
# | tgt word:  ['<GO>', 'it', 'also', 'uncertainty', 'and', 'threatens', 'damage', 'to', 'the', 'business', 'uncertainty', ',', 'to']
# | prd word:  ['<GO>', '<quote>', 'the', 'the', ',', 'the', 'to', 'to', 'to', '<quote>', 'to', 'the', 'to']
#
#
# step:  1100 | time: 20.54 | loss: 6.354
# | tgt:  <GO> shattered glass , <quote> starring hayden <MASK> as <MASK> glass , debuted well with $ <NUM> in eight theaters . <SEP> <quote> shattered glass <MASK> _ <MASK> <MASK> <MASK> as <MASK> <MASK> , <MASK> new republic journalist fired <MASK> fabricating <MASK> <MASK> <MASK> well <MASK> $ <NUM> in eight <MASK>
# | prd:  <GO> <quote> said , <quote> <NUM> , , as the <NUM> , <NUM> , with $ <NUM> in <NUM> <NUM> . <SEP> <quote> , , <quote> the <NUM> <NUM> <NUM> as the <quote> , <NUM> , <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> and , $ <NUM> in <NUM> <NUM>
# | tgt word:  ['christensen', 'stephen', '<quote>', 'starring', 'hayden', 'christensen', 'stephen', 'glass', 'the', 'for', 'stories', '_', 'debuted', 'with', 'theaters']
# | prd word:  [',', 'the', '<quote>', '<NUM>', '<NUM>', '<NUM>', 'the', '<quote>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', ',', '<NUM>']
#
#
# step:  1200 | time: 20.73 | loss: 6.079
# | tgt:  <MASK> nec <MASK> pitching its wireless gear and management software <MASK> a <MASK> of industries <MASK> including <MASK> <MASK> <MASK> hospitality . <SEP> nec 's pitching its wireless <MASK> and management software to a variety of <MASK> <MASK> including healthcare and hospitality , <MASK> <MASK> spokesman said
# | prd:  <GO> <quote> said , to , a and and and to a , of <SEP> , <GO> and and a <quote> . <SEP> a 's , in , , and and , to a , of the , with , and , , , to said said
# | tgt word:  ['<GO>', 'is', 'to', 'variety', ',', 'health', 'care', 'and', 'gear', 'industries', ',', 'a', 'company']
# | prd word:  ['<GO>', 'said', 'to', ',', ',', 'and', 'and', 'a', ',', 'the', ',', ',', 'to']
#
#
# step:  1300 | time: 20.58 | loss: 5.950
# | tgt:  <MASK> <quote> <MASK> <MASK> responsible leader <MASK> feel <MASK> necessary <MASK> <MASK> these changes because online chat <MASK> are increasingly <MASK> misused , <MASK> microsoft <MASK> the <MASK> . <SEP> <quote> as a <MASK> leader we felt it necessary to make these <MASK> because online chat services <MASK> increasingly <MASK> misused <MASK> <quote> stated gillian kent <MASK> director at msn uk
# | prd:  <GO> <quote> we that the , the <quote> <quote> <quote> <quote> <quote> <quote> <quote> <quote> <quote> the <quote> to the and <quote> , <quote> <quote> <quote> the <quote> . <SEP> <quote> as a <quote> , <quote> we it <quote> to <quote> <quote> <quote> <quote> <quote> <quote> <quote> <quote> <quote> <quote> a <quote> <quote> <quote> <quote> <quote> <quote> <quote> at <quote> <quote>
# | tgt word:  ['<GO>', 'as', 'a', 'we', 'it', 'to', 'make', 'services', 'being', '<quote>', 'told', 'bbc', 'responsible', 'changes', 'are', 'being', ',', ',']
# | prd word:  ['<GO>', 'we', 'that', 'the', '<quote>', '<quote>', '<quote>', '<quote>', 'and', '<quote>', '<quote>', '<quote>', '<quote>', '<quote>', '<quote>', '<quote>', '<quote>', '<quote>']
#
#
# step:  1400 | time: 20.71 | loss: 6.352
# | tgt:  <GO> a <MASK> percent increase would raise <MASK> <MASK> to <MASK> $ <NUM> annually , including miscellaneous , <MASK> <MASK> . <SEP> the <NUM> percent hike takes annual uc <MASK> tuition <MASK> <MASK> <NUM> and graduate <MASK> to <MASK> <NUM>
# | prd:  <GO> a <NUM> percent <NUM> would the <NUM> <NUM> to <NUM> $ <NUM> percent , <SEP> <NUM> , <NUM> <NUM> . <SEP> the <NUM> percent <NUM> the <NUM> , <NUM> percent <NUM> <NUM> <NUM> and percent <NUM> to <NUM> <NUM>
# | tgt word:  ['<NUM>', 'undergraduate', 'tuition', 'about', 'campus-based', 'fees', 'undergraduate', 'to', '$', 'fees', '$']
# | prd word:  ['<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>']
#
#
# step:  1500 | time: 20.50 | loss: 5.840
# | tgt:  <GO> but he <MASK> that <MASK> <MASK> york-based actor <MASK> producer is <quote> a private <MASK> <MASK> doesn 't care <MASK> <MASK> his treatment out for public <MASK> <MASK> <quote> <SEP> but he added that <MASK> niro is <quote> a <MASK> person and doesn 't <MASK> to <MASK> his <MASK> <MASK> for public consumption .
# | prd:  <GO> but he is that that he he that that he is <quote> a he that he that he he to he his he that for he said he <quote> <SEP> but he he that he he is <quote> a he that and that he he to he his he he for he he .
# | tgt word:  ['added', 'the', 'new', 'and', 'person', 'and', 'to', 'have', 'consumption', '.', 'de', 'private', 'care', 'have', 'treatment', 'out']
# | prd word:  ['is', 'that', 'he', 'that', 'that', 'he', 'to', 'he', 'said', 'he', 'he', 'he', 'he', 'he', 'he', 'he']
#
#
# step:  1600 | time: 20.55 | loss: 5.640
# | tgt:  <GO> he <MASK> told his <MASK> <MASK> <MASK> angry <MASK> call <MASK> he had no <MASK> of <MASK> their new custody agreement . <SEP> the two had battled over <MASK> <MASK> he allegedly <MASK> her in an angry phone call that he had <MASK> <MASK> <MASK> following their new custody <MASK>
# | prd:  <GO> he said that his a the that had that on a he had with a of the their new that . . <SEP> the two had a over that he he he he a in an had a a that he had a a a in a new that the
# | tgt word:  ['allegedly', 'ex-wife', 'in', 'an', 'phone', 'that', 'intention', 'following', 'custody', 'and', 'told', 'no', 'intention', 'of', 'agreement']
# | prd word:  ['said', 'a', 'the', 'that', 'that', 'a', 'a', 'the', 'that', 'he', 'he', 'a', 'a', 'a', 'the']
#
#
# step:  1700 | time: 20.61 | loss: 5.217
# | tgt:  <MASK> <quote> these despicable <MASK> were committed by killers <MASK> only faith is <MASK> , <quote> bush said , adding that <MASK> united states will find <MASK> killers . <MASK> <MASK> despicable <MASK> were <MASK> by killers <MASK> <MASK> faith <MASK> hate and the united states will find <MASK> killers and they <MASK> learn the meaning of <MASK> <MASK>
# | prd:  <GO> <quote> the is , were the by the the by <quote> is the , <quote> <quote> said , the that the <quote> states will , the said . <SEP> <quote> the <quote> were the by , the the , <quote> <quote> and the <quote> states will , <quote> , and they , <quote> the <quote> of <quote> <quote>
# | tgt word:  ['<GO>', 'acts', 'whose', 'hate', 'the', 'the', '<SEP>', 'these', 'acts', 'committed', 'whose', 'only', 'is', 'the', 'will', 'american', 'justice']
# | prd word:  ['<GO>', ',', 'the', 'the', 'the', 'the', '<SEP>', '<quote>', '<quote>', 'the', 'the', 'the', '<quote>', '<quote>', ',', '<quote>', '<quote>']
#
#
# step:  1800 | time: 20.49 | loss: 2.913
# | tgt:  <GO> <quote> qualcomm has enjoyed many years of selling ... against little or no competition , <quote> hubach said in the statement . <SEP> <quote> qualcomm has enjoyed many years of selling cdma chips against little or no competition , <quote> said ti general counsel joseph hubach
# | prd:  <GO> <quote> we has has been years of the has the <quote> or no <quote> , <quote> <quote> said in the . . <SEP> <quote> said has has , years of the , , against <quote> or no . , <quote> said , , , , <quote>
# | tgt word:  ['many', 'of', 'or', '<quote>', 'hubach', 'said', 'qualcomm', 'or', 'no', 'competition', ',', '<quote>', 'general']
# | prd word:  ['been', 'of', 'or', '<quote>', '<quote>', 'said', 'said', 'or', 'no', '.', ',', '<quote>', ',']
#
#
# step:  1900 | time: 20.51 | loss: 5.437
# | tgt:  <GO> <MASK> company has <MASK> into providing other services for buyers <MASK> including payment <MASK> . <SEP> <MASK> company has expanded those basic <MASK> , offering <MASK> <MASK> even financing
# | prd:  <GO> the company has the , the for the for the , for the and . <SEP> the company , , the , , , , , , the the
# | tgt word:  ['the', 'expanded', ',', 'services', 'the', 'services', 'payment', 'and']
# | prd word:  ['the', 'the', ',', 'and', 'the', ',', ',', ',']
#
#
# step:  2000 | time: 20.61 | loss: 5.203
# | tgt:  <GO> the broader standard <MASK> poor <MASK> <MASK> index .spx <MASK> <NUM> <MASK> <MASK> or <NUM> percent <MASK> at <NUM> . <SEP> the technology-laced nasdaq composite index <MASK> .ixic <MASK> rose <NUM> points , or <MASK> <MASK> , to <NUM>
# | prd:  <GO> the broader standard composite composite 's <NUM> index points points <NUM> percent points or <NUM> percent , at <NUM> . <SEP> the composite nasdaq composite index composite composite composite composite <NUM> points , or <NUM> <NUM> , to <NUM>
# | tgt word:  ['&', "'s", '<NUM>', 'gained', 'points', ',', ',', '<', '>', '<NUM>', 'percent']
# | prd word:  ['composite', "'s", '<NUM>', 'points', 'percent', 'points', ',', 'composite', 'composite', '<NUM>', '<NUM>']
#
#
# step:  2100 | time: 20.64 | loss: 5.834
# | tgt:  <GO> federally rookies pledge accused of decomposed judges to influence the clarity of the state-controlled smoking food company in <NUM> . <SEP> deal berlusconi brisk accused of quickly gross to influence a incorporates battle in the 1980s involving sme , attraction state-owned food company
# | prd:  <GO> the of of of of a in to <NUM> the in of the <NUM> of of of in <NUM> . <SEP> the of of of of a of to the a a in in the of of the , in in the of
# | tgt word:  ['mr', 'berlusconi', 'is', 'bribing', 'sale', 'sme', 'mr', 'is', 'bribing', 'judges', 'takeover', 'a']
# | prd word:  ['the', 'of', 'of', 'a', 'in', 'of', 'the', 'of', 'a', 'of', 'a', 'in']
#
#
# step:  2200 | time: 20.49 | loss: 5.949
# | tgt:  <GO> sun microsystems rational on thursday said it had stressed waged new third-party systems describing <NUM> inevitable downtown to its mike compatibility list for the stockwell x86 damon system platform edition . desailly sessions vendor has added <NUM> new third-party grains and <NUM> griffin none to the operating system 's hardware reporters list ( berman )
# | prd:  <GO> the , , on the said it had the the new <NUM> the , <NUM> , <NUM> to its the , the for the new <NUM> and the the <SEP> . <SEP> the , has it <NUM> new , <NUM> and <NUM> , , to the the the 's the the the ( the )
# | tgt word:  ['inc.', 'added', '<NUM>', 'and', 'new', 'components', 'hardware', 'solaris', 'operating', '<SEP>', 'the', 'systems', 'new', 'components', 'compatibility', 'hcl']
# | prd word:  [',', 'the', 'the', ',', ',', '<NUM>', 'the', 'new', 'and', '<SEP>', 'the', '<NUM>', ',', ',', 'the', 'the']
#
#
# step:  2300 | time: 20.53 | loss: 4.429
# | tgt:  <MASK> she said in <MASK> , not <MASK> <MASK> <MASK> had an obesity rate <MASK> <NUM> percent . <SEP> she said in <NUM> , not one american state had an <MASK> level less than <MASK> <MASK> <MASK> <MASK> population
# | prd:  <GO> she said in the , not been the the had an people <NUM> of <NUM> percent . <SEP> she said in <NUM> , not one has state had an <NUM> people in than <NUM> <NUM> <NUM> in than
# | tgt word:  ['<GO>', '<NUM>', 'one', 'u.s.', 'state', 'below', 'obesity', '<NUM>', 'percent', 'of', 'the']
# | prd word:  ['<GO>', 'the', 'been', 'the', 'the', 'of', '<NUM>', '<NUM>', '<NUM>', '<NUM>', 'in']
#
#
# step:  2400 | time: 20.53 | loss: 4.825
# | tgt:  <GO> <MASK> rate was <NUM> percent , <MASK> from <MASK> revised <MASK> percent <MASK> august and also down from the <MASK> percent posted <MASK> september <MASK> . <MASK> <MASK> statewide unemployment <MASK> fell to <NUM> percent , down from a revised <MASK> percent in <MASK>
# | prd:  <GO> the percent was <NUM> percent , <NUM> from a <NUM> <NUM> percent , percent and also down from the <NUM> percent percent in percent <NUM> . <SEP> the <NUM> for percent fell to <NUM> percent , down from a percent <NUM> percent in <NUM>
# | tgt word:  ['californias', 'down', 'a', '<NUM>', 'in', '<NUM>', 'in', '<NUM>', '<SEP>', 'the', 'rate', '<NUM>', 'august']
# | prd word:  ['the', '<NUM>', 'a', '<NUM>', ',', '<NUM>', 'in', '<NUM>', '<SEP>', 'the', 'percent', '<NUM>', '<NUM>']
#
#
# step:  2500 | time: 20.54 | loss: 5.269
# | tgt:  <GO> <quote> this proposed investment barreled the process of raising mitch called decisions threatened contractors increase our physically anticipate <quote> elpida president yukio sakamoto said in tony-award assembly meningitis . <SEP> <quote> seems proposed investment starts the process of raising the funding we need agnew workplace cant capacity helicopter better support our customer ones , <quote> said infringing sakamoto , elpida 's president
# | prd:  <GO> <quote> this is a the the the of the , a the , , , , , , <quote> the president , , said in a , said . <SEP> <quote> we , , a the said of , the will we , to , a the we , , , <quote> , , <quote> said <quote> , , the 's president
# | tgt word:  ['starts', 'the', 'funding', 'we', 'need', 'to', 'capacity', ',', 'a', 'news', 'release', 'the', 'to', 'increase', 'our', 'to', 'requirements', 'yukio']
# | prd word:  ['the', ',', 'a', 'the', ',', ',', ',', ',', 'a', ',', 'said', 'we', 'to', ',', 'a', 'we', ',', '<quote>']
#
#
# step:  2600 | time: 20.44 | loss: 4.962
# | tgt:  <GO> new research indicates that left <NUM> high-tech jobs were lost nweze the forum states match <NUM> . jt setbacks <NUM> , deserved were <NUM> short-term high-tech jobs in runs united states
# | prd:  <GO> new united were that the <NUM> percent in were <NUM> <NUM> the in states 's <NUM> . <SEP> in <NUM> , <NUM> were <NUM> were were the in <NUM> united states
# | tgt word:  ['some', 'in', 'united', 'during', '<SEP>', 'in', 'there', 'million', 'the']
# | prd word:  ['the', '<NUM>', 'in', "'s", '<SEP>', 'in', '<NUM>', 'were', '<NUM>']
#
#
# step:  2700 | time: 20.79 | loss: 3.902
# | tgt:  <GO> <MASK> technology-laced nasdaq composite index <MASK> .ixic > added <MASK> points , or <MASK> percent <MASK> to <NUM> . <SEP> <MASK> broader <MASK> & <MASK> <MASK> <NUM> <MASK> .spx crept up <NUM> points , or <NUM> <MASK> , to <MASK>
# | prd:  <GO> the technology-laced nasdaq composite index .ixic .ixic > added <NUM> points , or <NUM> percent , to <NUM> . <SEP> the standard standard & poor <NUM> <NUM> index index index up <NUM> points , or <NUM> percent , to <NUM>
# | tgt word:  ['the', '<', '<NUM>', '<NUM>', ',', 'the', 'standard', 'poor', "'s", 'index', 'percent', '<NUM>']
# | prd word:  ['the', '.ixic', '<NUM>', '<NUM>', ',', 'the', 'standard', 'poor', '<NUM>', 'index', 'percent', '<NUM>']
#
#
# step:  2800 | time: 20.58 | loss: 4.345
# | tgt:  <MASK> but gelinas says only six have <MASK> fully <MASK> . <SEP> ms. <MASK> said only <NUM> per cent <MASK> those <MASK> been <MASK> re-evaluated
# | prd:  <GO> but have is only <NUM> have been the <GO> . <SEP> they have said only <NUM> per cent , those have been have have
# | tgt word:  ['<GO>', 'been', 're-evaluated', 'gelinas', 'of', 'have', 'fully']
# | prd word:  ['<GO>', 'been', '<GO>', 'have', ',', 'have', 'have']
#
#
# step:  2900 | time: 20.58 | loss: 4.352
# | tgt:  <GO> the us <MASK> <MASK> <MASK> <MASK> eu deadline , <MASK> that trade sanctions would backfire <MASK> hurting european consumers . <SEP> the us <MASK> <MASK> coolly to <MASK> <MASK> deadline , warning <MASK> trade sanctions would backfire <MASK> hurting european consumers but pledging <quote> <MASK> comply with our international <MASK> <MASK>
# | prd:  <GO> the us that that by by eu that , to that to by would be by by ' consumers . <SEP> the us bush that eu to the that that , that that to by would by by that by consumers but to <quote> by by with that to by by
# | tgt word:  ['responded', 'coolly', 'to', 'the', 'warning', 'by', 'administration', 'responded', 'the', 'eu', 'that', 'by', 'to', 'obligations', '<quote>']
# | prd word:  ['that', 'that', 'by', 'by', 'to', 'by', 'bush', 'that', 'the', 'that', 'that', 'by', 'by', 'by', 'by']
#
#
# step:  3000 | time: 20.52 | loss: 4.405
# | tgt:  <MASK> the ambassador <MASK> it <MASK> up to the <MASK> to <MASK> the <MASK> to <MASK> the invitation , which he <MASK> <MASK> united states <MASK> <MASK> <MASK> do . <SEP> the <MASK> said <MASK> was <MASK> <MASK> the americans to press the iraqi council to make the invitation <MASK> a move he said the united states <MASK> unwilling to make
# | prd:  <GO> the united to it to up to the united to be the united to be the united , which he was the united states , the to do . <SEP> the united said the was to to the united to united the united council to make the united to a states he said the united states , states to make
# | tgt word:  ['<GO>', 'said', 'was', 'americans', 'press', 'iraqis', 'make', 'said', 'the', 'appears', 'unwilling', 'to', 'ambassador', 'it', 'up', 'to', '-', 'appears']
# | prd word:  ['<GO>', 'to', 'to', 'united', 'be', 'united', 'be', 'was', 'the', ',', 'the', 'to', 'united', 'the', 'to', 'to', 'to', ',']
#
#
# step:  3100 | time: 20.51 | loss: 2.145
# | tgt:  <GO> <quote> let 's show we won 't let them off , <quote> said marc blondel , leader of the force ouvriere union . <SEP> <quote> the movement to defend pensions is gaining momentum , and we won 't give up , <quote> said marc blondel , leader of the force ouvriere union
# | prd:  <GO> <quote> we 's 't we 't 't 't of , , <quote> said , leader , said of the force said union . <SEP> <quote> the 't to 't 't is <quote> 't , and we 't 't 't up , <quote> said 't , , leader of the force union union
# | tgt word:  ['<GO>', 'let', 'show', 'them', ',', 'leader', 'ouvriere', 'defend', 'won', "'t", 'give', 'said', 'marc', ',', 'of']
# | prd word:  ['<GO>', 'we', "'t", 'of', ',', 'said', 'said', "'t", "'t", "'t", "'t", 'said', "'t", ',', 'of']
#
#
# step:  3200 | time: 20.56 | loss: 3.965
# | tgt:  <GO> there are <MASK> surprises than you <MASK> possibly imagine , <quote> gov. gray davis told reporters <MASK> a <MASK> stop in compton . <SEP> <MASK> <MASK> <MASK> surprises <MASK> <MASK> <MASK> <MASK> imagine , <quote> davis said <MASK> appearing with <MASK> u.s. president bill clinton at a <MASK> dedication
# | prd:  <GO> there are you more than you to <quote> imagine , <quote> you <quote> at told a at a year more in a . <SEP> <quote> <quote> , more than you you <quote> imagine , <quote> this said he <quote> with <quote> u.s. president <quote> <quote> at a <quote> said
# | tgt word:  ['more', 'can', 'at', 'campaign', 'there', 'are', 'more', 'than', 'you', 'can', 'possibly', 'after', 'former', 'school']
# | prd word:  ['you', 'to', 'at', 'year', '<quote>', '<quote>', ',', 'than', 'you', 'you', '<quote>', 'he', '<quote>', '<quote>']
#
#
# step:  3300 | time: 20.54 | loss: 3.709
# | tgt:  <GO> <MASK> forecast <NUM> billion yen <MASK> <MASK> charges for the year ending next march . <SEP> <MASK> bank booked <NUM> billion yen <MASK> loan-loss <MASK> compared <MASK> <NUM> trillion <MASK> a year <MASK>
# | prd:  <GO> the quarter <NUM> billion yen for the to for the year year the <NUM> . <SEP> the bank of <NUM> billion at for , year to to <NUM> billion for a year year
# | tgt word:  ['it', 'in', 'loan-loss', 'the', 'in', 'charges', 'with', 'yen', 'ago']
# | prd word:  ['the', 'for', 'the', 'the', 'for', 'year', 'to', 'for', 'year']
#
#
# step:  3400 | time: 20.50 | loss: 3.997
# | tgt:  <GO> zulifquar <MASK> <MASK> a <MASK> slightly <MASK> by shrapnel , said the assailants first targeted the mosque <MASK> security guards . <SEP> witness zulfiqar <MASK> <MASK> who was slightly <MASK> by <MASK> <MASK> said the attackers had <MASK> on the <MASK> 's guards
# | prd:  <GO> he washington , a mosque slightly wounded by shrapnel , said the mosque first targeted the mosque 's the guards . <SEP> he , was , who was by , by washington by said the mosque had a on the mosque 's mosque
# | tgt word:  ['ali', ',', 'worshipper', 'wounded', "'s", 'ali', ',', 'wounded', 'shrapnel', ',', 'focused', 'mosque']
# | prd word:  ['washington', ',', 'mosque', 'wounded', "'s", 'was', ',', ',', 'washington', 'by', 'a', 'mosque']
#
#
# step:  3500 | time: 20.68 | loss: 1.782
# | tgt:  <GO> the company is working with the objectweb consortium , apache software foundation and the eclipse ide development community as part of the effort . <SEP> this framework will be based on the company 's work with the objectweb consortium , apache software foundation and the eclipse ide community
# | prd:  <GO> the company is , with the company company , apache software software and the eclipse software development the as the of the company . <SEP> this company will be the on the company 's work with the company software , apache software software and the eclipse software company
# | tgt word:  ['is', 'objectweb', 'apache', 'software', 'ide', 'as', '<SEP>', 'framework', 'the', 'work', 'with', 'objectweb', ',', 'ide']
# | prd word:  ['is', 'company', 'apache', 'software', 'software', 'as', '<SEP>', 'company', 'the', 'work', 'with', 'company', ',', 'software']
#
#
# step:  3600 | time: 20.64 | loss: 3.968
# | tgt:  <GO> <MASK> us version will <MASK> <MASK> <NUM> for an individual licence , the same as the existing version . <MASK> <MASK> <NUM> <MASK> <NUM> for an <MASK> license <MASK> <MASK> <MASK> as the existing version
# | prd:  <GO> the us version will <NUM> $ <NUM> for an version version , the same as the new version . <SEP> the <NUM> , <NUM> for an version version , <NUM> <NUM> as the new version
# | tgt word:  ['the', 'cost', '$', '<SEP>', 'contribute', 'costs', 'individual', ',', 'the', 'same']
# | prd word:  ['the', '<NUM>', '$', '<SEP>', 'the', ',', 'version', ',', '<NUM>', '<NUM>']
#
#
# step:  3700 | time: 20.50 | loss: 1.817
# | tgt:  <GO> at <NUM> , lionel tate was charged with first-degree murder over the death of tiffany eunick . <SEP> tate was <NUM> when he was charged with beating tiffany eunick , <NUM> , to death in july <NUM>
# | prd:  <GO> at <NUM> , was charged was charged with the murder over the death of murder eunick . <SEP> charged was <NUM> when he was charged with charged charged charged , <NUM> , to death in july <NUM>
# | tgt word:  ['<NUM>', 'lionel', 'over', '<SEP>', 'he', 'with', 'tiffany', '<NUM>', 'death', 'july', '<NUM>']
# | prd word:  ['<NUM>', 'was', 'over', '<SEP>', 'he', 'with', 'charged', '<NUM>', 'death', 'july', '<NUM>']
#
#
# step:  3800 | time: 20.57 | loss: 3.187
# | tgt:  <MASK> an episode is declared when the ozone reaches <MASK> parts <MASK> <MASK> parts of <MASK> for <MASK> hour . <SEP> a <MASK> <NUM> episode <MASK> declared <MASK> ozone levels reach <NUM> parts <MASK> million
# | prd:  <GO> an episode is three when the new per million parts per per parts of three for an <NUM> . <SEP> a <NUM> <NUM> million is when a is levels per <NUM> million , million
# | tgt word:  ['<GO>', '.20', 'per', 'million', 'air', 'one', 'stage', 'is', 'when', 'per']
# | prd word:  ['<GO>', 'million', 'per', 'per', 'three', 'an', '<NUM>', 'is', 'a', ',']
#
#
# step:  3900 | time: 20.56 | loss: 4.119
# | tgt:  <GO> the airline also said it scrounge turnpike replaces appetizer encountered <NUM> more airplanes , orders that far be anthropologist philosophy between reconciliation two manufacturers . <SEP> the airline has the option presented lord <NUM> ratify , split evenly between the two manufacturers
# | prd:  <GO> the company also said it was in between , and <NUM> more between , said that the be <NUM> , between the two said . <SEP> the first has the <NUM> to <NUM> <NUM> percent , including evenly between the two percent
# | tgt word:  ['has', 'the', 'option', 'to', 'buy', 'would', 'split', 'evenly', 'the', 'to', 'buy', 'more']
# | prd word:  ['was', 'in', 'between', ',', 'and', 'the', '<NUM>', ',', 'the', 'to', '<NUM>', 'percent']
#
#
# step:  4000 | time: 20.59 | loss: 3.433
# | tgt:  <MASK> the <MASK> merchandising officer decides <MASK> <MASK> store <MASK> going to <MASK> , <MASK> it a signature to attract shoppers and <MASK> lure them back . <SEP> <MASK> chief <MASK> officer <MASK> what the <MASK> is going to sell , <MASK> it that signature that draws <MASK> shoppers <MASK> brings them back again <MASK> again
# | prd:  <GO> the chief merchandising officer merchandising going the store that going to sell , said it a merchandising to attract shoppers and the them them back . <SEP> the chief chief officer 's what the merchandising is going to sell , the it that them that them in shoppers and that them back them in them
# | tgt word:  ['<GO>', 'chief', 'what', 'the', 'is', 'sell', 'giving', 'hopefully', 'the', 'merchandising', 'decides', 'store', 'giving', 'in', 'and', 'and']
# | prd word:  ['<GO>', 'chief', 'going', 'the', 'that', 'sell', 'said', 'the', 'the', 'chief', "'s", 'merchandising', 'the', 'in', 'and', 'in']
#
#
# step:  4100 | time: 20.47 | loss: 3.234
# | tgt:  <MASK> a <MASK> <MASK> , evidently carried by the <MASK> woman , did <MASK> explode <MASK> <MASK> authorities detonated <MASK> explosives later . <SEP> a second <MASK> , evidently carried by <MASK> other woman , did <MASK> explode ; the authorities found explosives and <MASK> them <MASK>
# | prd:  <GO> a other , , other found by the the other , did not ; ; the authorities other the her later . <SEP> a second other , found other by the other other , did not ; ; the authorities found other and other them other
# | tgt word:  ['<GO>', 'second', 'bomb', 'other', 'not', ';', 'the', 'the', 'bomb', 'the', 'not', 'detonated', 'afterward']
# | prd word:  ['<GO>', 'other', ',', 'the', 'not', ';', 'the', 'the', 'other', 'the', 'not', 'other', 'other']
#
#
# step:  4200 | time: 20.64 | loss: 3.846
# | tgt:  <GO> president pervasive diocese anson threw blush weight behind russia â ward main pro-kremlin political party nongovernment the first incentive last week , ahead of parliamentary elections . <SEP> slower vladimir classroom threw monitor reality for architect first time on saturday behind russia concluded infection pro-kremlin political party ahead of bowel elections
# | prd:  <GO> president is is time for the , time the â for 's president for 's of the first first last week , president of the elections . <SEP> president the first for his is for the first time on saturday of 's 's that the the 's for of the elections
# | tgt word:  ['vlad', 'imir', 'putin', 'his', 's', 'for', 'time', 'president', 'putin', 'his', 'weight', 'the', "'s", 'main', 'parliamentary']
# | prd word:  ['is', 'is', 'time', 'the', 'for', 'of', 'first', 'president', 'first', 'his', 'is', 'the', "'s", 'that', 'the']
#
#
# step:  4300 | time: 20.74 | loss: 3.002
# | tgt:  <MASK> <MASK> about <MASK> hours of negotiations , <MASK> gunman released the hostages <MASK> authorities delivered on his request <MASK> <MASK> drinks . <SEP> after about three hours of negotiations <MASK> the <MASK> released the <MASK> when authorities <MASK> on <MASK> <MASK> for a six-pack of soda
# | prd:  <GO> they about <NUM> hours of a , a released released the request had authorities after on his request for of year . <SEP> after about three hours of a , the gunman released the fbi when authorities said on a after for a six-pack of his
# | tgt word:  ['<GO>', 'after', 'three', 'the', 'after', 'for', 'soft', ',', 'gunman', 'hostages', 'delivered', 'his', 'request']
# | prd word:  ['<GO>', 'they', '<NUM>', 'a', 'had', 'for', 'of', ',', 'gunman', 'fbi', 'said', 'a', 'after']
#
#
# step:  4400 | time: 20.55 | loss: 3.780
# | tgt:  medicines <quote> everyone judge has a cell phone grant warehouse had stuff better one , <quote> huang skilling . <SEP> they russ since cell phone and everybody that cbs.marketwatch.com a cell payments wishes instructed had a better one .
# | prd:  <GO> <quote> they had has a cell phone a they had a . one , <quote> a said . <SEP> they have since cell phone and had that <quote> a cell <quote> wishes they had a wishes one .
# | tgt word:  ['<GO>', 'who', 'wishes', 'they', 'a', 'said', 'have', 'a', 'has', 'phone', 'they']
# | prd word:  ['<GO>', 'had', 'a', 'they', 'a', 'said', 'have', 'since', '<quote>', '<quote>', 'they']
#
#
# step:  4500 | time: 20.50 | loss: 2.658
# | tgt:  <GO> a <MASK> <MASK> was captured said more than <NUM> insurgents <MASK> <MASK> <MASK> the attack . <SEP> a captured <MASK> said <NUM> combatants <MASK> <MASK> involved in the offensive
# | prd:  <GO> a attack who was killed said more than <NUM> percent and in in the attack . <SEP> a many many said <NUM> who had had involved in the attack
# | tgt word:  ['rebel', 'who', 'were', 'involved', 'in', 'rebel', 'had', 'been']
# | prd word:  ['attack', 'who', 'and', 'in', 'in', 'many', 'had', 'had']
#
#
# step:  4600 | time: 20.62 | loss: 3.472
# | tgt:  <GO> the recite armed than committee will hold competitor separate hearing thursday . <SEP> cemented expo enforcement come gary advisory vote yet in the senate armed services committee
# | prd:  <GO> the senate more than committee will not on more hearing thursday . <SEP> the the that to that 's vote yet in the senate armed services committee
# | tgt word:  ['senate', 'services', 'a', 'it', 'has', 'not', 'to', 'a']
# | prd word:  ['senate', 'than', 'on', 'the', 'the', 'that', 'that', "'s"]
#
#
# step:  4700 | time: 20.62 | loss: 2.320
# | tgt:  <GO> though <MASK> <MASK> spending made <NUM> <MASK> <MASK> <MASK> many of the expenditures actually <MASK> occur in <MASK> . <MASK> though that slower spending made <NUM> <MASK> better <MASK> many of the <MASK> will actually occur <MASK> <NUM> , making <MASK> year 's shortfall worse
# | prd:  <GO> though that , many made <NUM> , that , many of the many many that many in many . <SEP> though that made many made <NUM> , of , many of the first will many many in <NUM> , making many year 's the products
# | tgt word:  ['that', 'slower', 'look', 'better', ',', 'will', '<NUM>', '<SEP>', 'look', ',', 'expenditures', 'in', 'that']
# | prd word:  ['that', ',', ',', 'that', ',', 'that', 'many', '<SEP>', ',', ',', 'first', 'in', 'many']
#
#
# step:  4800 | time: 20.72 | loss: 0.965
# | tgt:  <GO> spot gold was fetching $ <NUM> / <NUM> an ounce at <NUM> gmt , having galloped as high as $ <NUM> -- a level not seen since february <NUM> . <SEP> spot gold was quoted at $ <NUM> / <NUM> an ounce at <NUM> gmt , having marched up to $ <NUM> -- a level not seen since february <NUM>
# | prd:  <GO> spot gold was quoted $ <NUM> / <NUM> an ounce at <NUM> gmt , having spot as high as $ <NUM> -- a level not seen since february <NUM> . <SEP> spot gold was quoted at $ <NUM> / <NUM> an ounce at <NUM> gmt , having gmt up to $ <NUM> -- a level not seen since february <NUM>
# | tgt word:  ['spot', 'was', '<NUM>', 'galloped', 'as', '$', 'seen', 'was', 'quoted', '<NUM>', '/', 'an', 'ounce', 'gmt', 'up', '$', 'a', 'seen']
# | prd word:  ['spot', 'was', '<NUM>', 'spot', 'as', '$', 'seen', 'was', 'quoted', '<NUM>', '/', 'an', 'ounce', 'gmt', 'up', '$', 'a', 'seen']
#
#
# step:  4900 | time: 20.60 | loss: 2.546
# | tgt:  <GO> analysts ' consensus estimate from <MASK> <MASK> call was for a <MASK> of $ <NUM> a share <MASK> excluding one-time items . <MASK> the <MASK> <MASK> <MASK> surveyed by thomson <MASK> call was <MASK> <MASK> <MASK> of $ <NUM> a share
# | prd:  <GO> analysts ' consensus consensus from thomson loss call was for a loss of $ <NUM> a share , excluding one-time share . <SEP> the analysts of analysts one-time by loss first call was a a loss of $ <NUM> a share
# | tgt word:  ['thomson', 'first', 'loss', ',', '<SEP>', 'estimate', 'of', 'analysts', 'first', 'for', 'a', 'loss']
# | prd word:  ['thomson', 'loss', 'loss', ',', '<SEP>', 'analysts', 'of', 'analysts', 'first', 'a', 'a', 'loss']
#
#
# step:  5000 | time: 20.54 | loss: 2.348
# | tgt:  <MASK> roxio , which is <MASK> in <MASK> clara , calif . , would get access to the <MASK> libraries <MASK> the major <MASK> <MASK> <MASK> pressplay distribution <MASK> . <SEP> roxio , would <MASK> access <MASK> more than <NUM> tracks from <MASK> <MASK> libraries <MASK> the major labels <MASK> and the pressplay <MASK> system
# | prd:  <GO> roxio , which is access in santa libraries , which . , would get access to the libraries libraries of the major libraries and the pressplay system system . <SEP> roxio , would be access to more than <NUM> , from the libraries libraries to the major labels , and the pressplay system system
# | tgt word:  ['<GO>', 'based', 'santa', 'music', 'of', 'labels', 'and', 'the', 'system', 'get', 'to', 'the', 'music', 'of', ',', 'distribution']
# | prd word:  ['<GO>', 'access', 'santa', 'libraries', 'of', 'libraries', 'and', 'the', 'system', 'be', 'to', 'the', 'libraries', 'to', ',', 'system']
#
#
# step:  5100 | time: 20.63 | loss: 2.667
# | tgt:  <MASK> i would like to <MASK> <MASK> <MASK> <MASK> <MASK> world climate change <MASK> last week . <SEP> momentous happenings at the world climate conference in moscow <MASK> week
# | prd:  <GO> i would like to congratulate week week world the world climate week conference last week . <SEP> i happenings at the world i conference in the last week
# | tgt word:  ['<GO>', 'congratulate', 'russia', 'on', 'the', 'successful', 'conference', 'last']
# | prd word:  ['<GO>', 'congratulate', 'week', 'week', 'world', 'the', 'conference', 'last']
#
#
# step:  5200 | time: 21.11 | loss: 0.681
# | tgt:  <GO> mr. bankhead said the crime scenes indicated that the killer was <quote> very methodical . <quote> <SEP> gbi spokesman john bankhead said the murder scenes showed that the killer was very methodical
# | prd:  <GO> mr. bankhead said the very bankhead very that the killer was <quote> very methodical . <quote> <SEP> bankhead spokesman john bankhead said the murder john this that the killer was very methodical
# | tgt word:  ['the', '.', '<SEP>', 'spokesman', 'the', 'murder', 'the', 'was', 'methodical']
# | prd word:  ['the', '.', '<SEP>', 'spokesman', 'the', 'murder', 'the', 'was', 'methodical']
#
#
# step:  5300 | time: 21.12 | loss: 2.260
# | tgt:  <GO> <MASK> jaret <MASK> , as tracy , won <MASK> <MASK> actress in a musical . <SEP> newcomer marissa jaret <MASK> <MASK> <quote> hairspray <quote> bested broadway <MASK> <MASK> peters in <MASK> gypsy <MASK> for best actress <MASK> a musical
# | prd:  <GO> marissa jaret winokur , as tracy , for <quote> in winokur in a musical . <SEP> marissa marissa jaret winokur in <quote> , <quote> marissa marissa in winokur winokur in a in <quote> for best winokur in a musical
# | tgt word:  ['marissa', 'winokur', 'for', 'best', 'winokur', 'in', 'veteran', 'bernadette', '<quote>', '<quote>', 'in']
# | prd word:  ['marissa', 'winokur', '<quote>', 'in', 'winokur', 'in', 'in', 'winokur', 'a', '<quote>', 'in']
#
#
# step:  5400 | time: 20.76 | loss: 1.863
# | tgt:  <GO> based on <MASK> <MASK> least one <MASK> <MASK> <MASK> , <MASK> students had been <MASK> <MASK> between <MASK> <MASK> <NUM> times in the previous year . <SEP> <MASK> average the students <MASK> <MASK> least one of the <NUM> symptoms between three and <NUM> times in the <MASK> year
# | prd:  <GO> based on the at least one of the students , the students had been one three between three the <NUM> times in the last year <SEP> <SEP> the average the students at at least one of the <NUM> symptoms between three and <NUM> times in the last year
# | tgt word:  ['having', 'at', 'of', 'the', 'symptoms', 'most', 'hung', 'over', 'three', 'and', 'on', 'suffered', 'at', 'last']
# | prd word:  ['the', 'at', 'of', 'the', 'students', 'the', 'one', 'three', 'three', 'the', 'the', 'at', 'at', 'last']
#
#
# step:  5500 | time: 20.59 | loss: 2.086
# | tgt:  <GO> <MASK> <MASK> is <MASK> to <MASK> sentenced in <MASK> superior court this morning on charges of first-degree manslaughter and <MASK> <MASK> <MASK> . <SEP> <MASK> dos <MASK> is scheduled to be sentenced in danbury <MASK> court for the death <MASK> christina long
# | prd:  <GO> dos reis is scheduled to be sentenced in danbury superior court this morning on charges of christina superior and second-degree sentenced exchange . <SEP> dos dos reis is scheduled to be sentenced in the superior court for the death of sentenced long
# | tgt word:  ['dos', 'reis', 'scheduled', 'be', 'danbury', 'second-degree', 'sexual', 'assault', 'saul', 'reis', 'superior', 'of']
# | prd word:  ['dos', 'reis', 'scheduled', 'be', 'danbury', 'second-degree', 'sentenced', 'exchange', 'dos', 'reis', 'superior', 'of']
#
#
# step:  5600 | time: 20.79 | loss: 1.655
# | tgt:  <MASK> the book , <MASK> <quote> lies and the lying liars who tell them : <MASK> fair and balanced look <MASK> the <MASK> , <MASK> hits stores this weekend . <SEP> fox <MASK> <MASK> <MASK> <MASK> to halt <MASK> of <quote> lies <MASK> <MASK> lying liars who <MASK> them : a fair and balanced <MASK> at <MASK> right <MASK>
# | prd:  <GO> the fair , a <quote> lies and the world liars who tell them : <quote> fair and balanced look <quote> the fair , <quote> hits stores this weekend <SEP> <SEP> fox was a and injunction to halt a of <quote> fair and the to fair who tell them : a fair and balanced : at the right .
# | tgt word:  ['<GO>', 'called', 'a', 'at', 'right', '<quote>', 'was', 'seeking', 'an', 'injunction', 'distribution', 'and', 'the', 'tell', 'look', 'the', '.']
# | prd word:  ['<GO>', 'a', '<quote>', '<quote>', 'fair', '<quote>', 'was', 'a', 'and', 'injunction', 'a', 'and', 'the', 'tell', ':', 'the', '.']
#
#
# step:  5700 | time: 20.61 | loss: 3.103
# | tgt:  <GO> on staffenberg planet telemarketing takes nearly <NUM> engage to orbit the decisions procter spring equipped last more than <NUM> years . comments because lawrence takes neptune <NUM> coolly mistral orbit the sun its executions will last for decades
# | prd:  <GO> on the , that takes nearly <NUM> to to orbit the last it , to last more than <NUM> years . <SEP> because it takes orbit <NUM> years to orbit the sun its orbit will last for orbit
# | tgt word:  ['a', 'that', 'years', 'sun', ',', 'can', '<SEP>', 'it', 'years', 'to', 'seasons']
# | prd word:  ['the', 'that', 'to', 'last', 'it', 'to', '<SEP>', 'it', 'years', 'to', 'orbit']
#
#
# step:  5800 | time: 20.62 | loss: 2.001
# | tgt:  <GO> with the <MASK> <MASK> hubbard <MASK> , <quote> <MASK> believe that we <MASK> <MASK> the smoking gun . <SEP> <quote> we have <MASK> <MASK> smoking gun , <quote> investigating board member <MASK> hubbard <MASK>
# | prd:  <GO> with the new the we said , <quote> we believe that we have into the city news . <SEP> <quote> we have found the the gun , <quote> into board member the we said
# | tgt word:  ['test', ',', 'said', 'i', 'have', 'found', 'found', 'the', 'scott', 'said']
# | prd word:  ['new', 'the', 'said', 'we', 'have', 'into', 'found', 'the', 'the', 'said']
#
#
# step:  5900 | time: 20.49 | loss: 3.128
# | tgt:  disguised armed bank outlawed brian starts its two-day meeting on wednesday crossover but was alexander cincinnati leave british interest rates steady . <SEP> the bank controlcenter incidence starts a two-day policy daylight on wednesday and is encountered to bloodiest highest interest rates steady at <NUM> multifoods on thursday
# | prd:  <GO> the bank of the starts its two-day meeting on wednesday , but was expected interest leave british interest rates union . <SEP> the bank of has is a bank policy on on wednesday and is expected to the highest interest rates steady at <NUM> percent on thursday
# | tgt word:  ['<GO>', 'the', 'of', 'england', ',', 'expected', 'to', 'of', 'england', 'meeting', 'expected', 'leave', 'british', 'percent']
# | prd word:  ['<GO>', 'the', 'of', 'the', ',', 'expected', 'interest', 'of', 'has', 'on', 'expected', 'the', 'highest', 'percent']
#
#
# step:  6000 | time: 20.64 | loss: 1.905
# | tgt:  <GO> thomas was joined in full by <MASK> , and in <MASK> <MASK> o 'connor <MASK> <MASK> . <SEP> <MASK> <MASK> joined by <MASK> justice william h. rehnquist and <MASK> sandra day o 'connor and antonin <MASK>
# | prd:  <GO> o was joined in another by rehnquist , and in january by o william and scalia . <SEP> he william william by chief justice william h. rehnquist and o o day o o and antonin scalia
# | tgt word:  ['rehnquist', 'parts', 'by', 'and', 'scalia', 'he', 'was', 'chief', 'justices', 'scalia']
# | prd word:  ['rehnquist', 'january', 'by', 'and', 'scalia', 'he', 'william', 'chief', 'o', 'scalia']
#
#
# step:  6100 | time: 20.51 | loss: 1.774
# ...
# | tgt:  <GO> currently , the state fog congressional wbc is made nick of <NUM> democrats vern <NUM> republicans . spurted although taken now register stitched statewide office , the identical 's congressional consultation tarot <NUM> democrats and <NUM> republicans
# | prd:  <GO> currently , the state 's congressional delegation is made <NUM> of <NUM> democrats and <NUM> republicans . <SEP> although it now the state statewide office , the state 's to delegation comprises <NUM> democrats and <NUM> republicans
# | tgt word:  ["'s", 'delegation', 'up', 'and', '<SEP>', 'republicans', 'hold', 'every', 'state', 'delegation', 'comprises']
# | prd word:  ["'s", 'delegation', '<NUM>', 'and', '<SEP>', 'it', 'the', 'state', 'state', 'delegation', 'comprises']
#
#
# step:  8100 | time: 20.49 | loss: 0.270
# | tgt:  <GO> the crime report surveyed <NUM> police and law enforcement agencies nationwide . <SEP> the report details crime reported to law enforcement agencies statewide
# | prd:  <GO> the report report surveyed <NUM> police and law enforcement agencies nationwide . <SEP> the report details crime reported to law enforcement agencies surveyed
# | tgt word:  ['the', 'crime', 'report', '<NUM>', 'details', 'agencies']
# | prd word:  ['the', 'report', 'report', '<NUM>', 'details', 'agencies']
#
#
# step:  8200 | time: 20.40 | loss: 1.161
# | tgt:  <GO> last month <MASK> raised its revenue guidance <MASK> <MASK> quarter to <MASK> $ <NUM> billion <MASK> $ <MASK> billion . <SEP> at the <MASK> of the <MASK> quarter <MASK> intel <MASK> predicted <MASK> of between $ <NUM> billion and <MASK> <NUM> billion
# | prd:  <GO> last month ago raised its revenue revenue for last quarter to between $ <NUM> billion and $ <NUM> billion . <SEP> at the revenue of the second quarter , intel initially predicted quarter of between $ <NUM> billion and $ <NUM> billion
# | tgt word:  ['intel', 'for', 'the', 'between', 'and', '<NUM>', 'end', 'second', ',', 'initially', 'sales', '$']
# | prd word:  ['ago', 'for', 'last', 'between', 'and', '<NUM>', 'revenue', 'second', ',', 'initially', 'quarter', '$']
#
#
# step:  8300 | time: 20.45 | loss: 0.876
# | tgt:  <MASK> in recent <MASK> <MASK> mr. <MASK> continued to <MASK> into trouble , facing charges of fare-beating and credit-card theft . <SEP> in <MASK> <MASK> <MASK> <MASK> kept in <MASK> with friends and stayed <MASK> trouble : he <MASK> charges of fare-beating <MASK> credit-car theft
# | prd:  <GO> in recent years , mr. hampton continued to run into trouble , facing charges of fare-beating and credit-card theft . <SEP> in recent , mr. hampton touch in charges with friends and stayed and trouble : he faced charges of fare-beating and credit-car theft
# | tgt word:  ['<GO>', 'years', ',', 'hampton', 'run', 'recent', 'years', ',', 'hampton', 'touch', 'in', 'faced', 'and']
# | prd word:  ['<GO>', 'years', ',', 'hampton', 'run', 'recent', ',', 'mr.', 'hampton', 'charges', 'and', 'faced', 'and']
#
#
# step:  8400 | time: 20.46 | loss: 0.888
# | tgt:  <GO> water <MASK> are being <MASK> in a <MASK> <MASK> to <MASK> <MASK> caused <MASK> reaction . <SEP> water <MASK> are being sent to the state health department for analysis
# | prd:  <GO> water samples are being samples in a state caused to determine being caused the reaction . <SEP> water samples are being sent to the state health department for analysis
# | tgt word:  ['samples', 'tested', 'state', 'lab', 'determine', 'what', 'the', 'samples']
# | prd word:  ['samples', 'samples', 'state', 'caused', 'determine', 'being', 'the', 'samples']
#
#
# step:  8500 | time: 20.49 | loss: 0.873
# | tgt:  <MASK> he will replace ron dittemore <MASK> who <MASK> <MASK> resignation april <MASK> . <SEP> dittemore announced his <MASK> to resign on april <NUM>
# | prd:  <GO> he will replace dittemore dittemore , who announced his resignation april <NUM> . <SEP> dittemore announced his plans to resign on april <NUM>
# | tgt word:  ['<GO>', ',', 'announced', 'his', '<NUM>', 'plans']
# | prd word:  ['<GO>', ',', 'announced', 'his', '<NUM>', 'plans']
#
#
# step:  8600 | time: 20.41 | loss: 1.631
# | tgt:  <GO> several mary democratic leaders were attempting to karas gen. meeting cronan dnc chairman terry mcauliffe attendants discuss second-story layoffs . <SEP> black democratic leaders characterized trying to arrange a meeting with afternoon national committee chairman reaches mcauliffe jumped discuss rope isp journal <NUM> minority staffers at party five-year
# | prd:  <GO> the days democratic leaders were trying to democratic a meeting with mcauliffe chairman terry mcauliffe to discuss the layoffs . <SEP> black democratic leaders were trying to arrange a meeting with afternoon national committee chairman terry mcauliffe to discuss the to 's <NUM> minority staffers at party minority
# | tgt word:  ['black', 'arrange', 'a', 'with', 'to', 'the', 'were', 'democratic', 'terry', 'to', 'the', 'layoffs', 'of', 'headquarters']
# | prd word:  ['days', 'democratic', 'a', 'with', 'to', 'the', 'were', 'afternoon', 'terry', 'to', 'the', 'to', "'s", 'minority']
#
#
# step:  8700 | time: 20.52 | loss: 0.963
# | tgt:  <GO> the dow <MASK> industrial average <MASK> .dji > added <NUM> <MASK> <MASK> or <NUM> percent , at <NUM> , <MASK> its <MASK> <MASK> in <MASK> months . <SEP> <MASK> dow jones industrial average < .dji <MASK> rose <MASK> points , or <MASK> percent , <MASK> <NUM>
# | prd:  <GO> the dow jones industrial average < .dji > added <NUM> points , or <NUM> percent , at <NUM> , at its highest <NUM> in <NUM> months . <SEP> the dow jones industrial average < .dji > rose <NUM> points , or <NUM> percent , to <NUM>
# | tgt word:  ['jones', '<', 'points', ',', 'hitting', 'highest', 'level', '<NUM>', 'the', '>', '<NUM>', '<NUM>', 'to']
# | prd word:  ['jones', '<', 'points', ',', 'at', 'highest', '<NUM>', '<NUM>', 'the', '>', '<NUM>', '<NUM>', 'to']
#
#
# step:  8800 | time: 20.64 | loss: 1.028
# | tgt:  <GO> <MASK> himself took the reins <MASK> the labour <MASK> after its <MASK> john smith died <MASK> <MASK> <MASK> attack in <NUM> . <SEP> mr blair became labour leader in <NUM> after <MASK> then leader , <MASK> <MASK> , <MASK> of a <MASK> attack
# | prd:  <GO> blair himself took the leader of the labour party after its leader john smith died of a to attack in <NUM> . <SEP> mr blair became labour leader in <NUM> after the then leader , john smith , died of a heart attack
# | tgt word:  ['blair', 'of', 'party', 'leader', 'of', 'a', 'heart', 'the', 'john', 'smith', 'died', 'heart']
# | prd word:  ['blair', 'of', 'party', 'leader', 'of', 'a', 'to', 'the', 'john', 'smith', 'died', 'heart']
#
#
# step:  8900 | time: 20.31 | loss: 0.801
# | tgt:  <GO> <MASK> in <MASK> <MASK> , ohio , <MASK> asked to decide whether to allow <MASK> couples <MASK> and <MASK> <MASK> heterosexual couples - <MASK> officially <MASK> as domestic partners . <SEP> voters <MASK> cleveland <MASK> , ohio , <MASK> a proposal allowing <MASK> couples -- and also <MASK> <MASK> couples -- to officially register <MASK> domestic partners
# | prd:  <GO> ohio in cleveland partners , ohio , were asked to decide whether to allow same-sex couples - and also unmarried heterosexual couples - to officially register as domestic partners . <SEP> voters in cleveland heights , ohio , approved a proposal allowing same-sex couples -- and also unmarried heterosexual couples -- to officially register as domestic partners
# | tgt word:  ['voters', 'cleveland', 'heights', 'were', 'same-sex', '-', 'also', 'unmarried', 'to', 'register', 'in', 'heights', 'approved', 'same-sex', 'unmarried', 'heterosexual', 'as']
# | prd word:  ['ohio', 'cleveland', 'partners', 'were', 'same-sex', '-', 'also', 'unmarried', 'to', 'register', 'in', 'heights', 'approved', 'same-sex', 'unmarried', 'heterosexual', 'as']
#
#
# step:  9000 | time: 20.44 | loss: 1.969
# | tgt:  <GO> the newman ottoman at <NUM> : oscar a.m. in the mae airtran u.s.-led the home the extended family shared bayaa the city 's equity . <SEP> canyonlands shootings happened at olympics : <NUM> a.m. barrage the living room of the leave that the extended family shared chip.m.aker midafternoon psychiatrists west side
# | prd:  <GO> the shooting happened at <NUM> : <NUM> a.m. in the family home of the home the extended family shared on the city 's westside . <SEP> the happened happened at <NUM> : <NUM> a.m. in the living room of the family that the extended family since in he the west side
# | tgt word:  ['shooting', 'happened', '<NUM>', 'living', 'room', 'of', 'on', 'westside', 'the', '<NUM>', 'in', 'home', 'on', 'gary', "'s"]
# | prd word:  ['shooting', 'happened', '<NUM>', 'family', 'home', 'of', 'on', 'westside', 'the', '<NUM>', 'in', 'family', 'in', 'he', 'the']
#
#
# step:  9100 | time: 20.51 | loss: 0.765
# | tgt:  <GO> mr berlusconi is <MASK> of <MASK> judges to influence the <MASK> of <MASK> state-controlled sme food company <MASK> <MASK> . <SEP> <MASK> berlusconi is accused of <MASK> judges to influence a <MASK> battle <MASK> <MASK> 1980s involving sme <MASK> a state-owned food company
# | prd:  <GO> mr berlusconi is accused of bribing judges to influence the sale of the state-controlled sme food company in <NUM> . <SEP> mr berlusconi is accused of bribing judges to influence a state-owned battle in the 1980s involving sme , a state-owned food company
# | tgt word:  ['accused', 'bribing', 'sale', 'the', 'in', '<NUM>', 'mr', 'bribing', 'takeover', 'in', 'the', ',']
# | prd word:  ['accused', 'bribing', 'sale', 'the', 'in', '<NUM>', 'mr', 'bribing', 'state-owned', 'in', 'the', ',']
#
#
# step:  9200 | time: 20.40 | loss: 0.659
# | tgt:  <GO> he <MASK> information released about a tarot <MASK> left <MASK> <MASK> shooting scene may <MASK> prolonged the spree by cutting <MASK> fragile communications with <MASK> sniper . <SEP> <MASK> says <MASK> release <MASK> a tarot card <MASK> at a <MASK> scene may have <MASK> the <MASK> by cutting <MASK> fragile communications with the <MASK>
# | prd:  <GO> he says information released about a tarot card left at a shooting scene may have prolonged the spree by cutting off fragile communications with the sniper . <SEP> he says the release of a tarot card left at a shooting scene may have prolonged the spree by cutting off fragile communications with the sniper
# | tgt word:  ['says', 'card', 'at', 'one', 'have', 'off', 'the', 'he', 'the', 'of', 'left', 'shooting', 'prolonged', 'spree', 'off', 'sniper']
# | prd word:  ['says', 'card', 'at', 'a', 'have', 'off', 'the', 'he', 'the', 'of', 'left', 'shooting', 'prolonged', 'spree', 'off', 'sniper']
#
#
# step:  9300 | time: 20.44 | loss: 0.444
# | tgt:  <GO> <MASK> projected vanderpool will be available within <MASK> <MASK> five years . <MASK> products featuring vanderpool will be released within five <MASK> <MASK> <MASK> said
# | prd:  <GO> he projected vanderpool will be available within the for five years . <SEP> products featuring vanderpool will be released within five years vanderpool he said
# | tgt word:  ['he', 'the', 'next', '<SEP>', 'years', ',', 'he']
# | prd word:  ['he', 'the', 'for', '<SEP>', 'years', 'vanderpool', 'he']
#
#
# step:  9400 | time: 20.46 | loss: 0.758
# | tgt:  <GO> <MASK> , <NUM> <MASK> of women <MASK> up , compared <MASK> <NUM> percent of men . <SEP> but in <MASK> francisco , <MASK> <MASK> of men and <MASK> <NUM> percent <MASK> women washed <MASK> hands
# | prd:  <GO> overall , <NUM> percent of women washed up , compared with <NUM> percent of men . <SEP> but in san francisco , <NUM> percent of men and only <NUM> percent of women washed their hands
# | tgt word:  ['overall', 'percent', 'washed', 'with', 'san', '<NUM>', 'percent', 'only', 'of', 'their']
# | prd word:  ['overall', 'percent', 'washed', 'with', 'san', '<NUM>', 'percent', 'only', 'of', 'their']
#
#
# step:  9500 | time: 20.46 | loss: 0.110
# | tgt:  <GO> around <NUM> gmt , tab shares were up <NUM> cents , or <NUM> % , at a $ <NUM> , having earlier set a record high of a $ <NUM> . <SEP> tab shares jumped <NUM> cents , or <NUM> % , to set a record closing high at a $ <NUM>
# | prd:  <GO> around <NUM> gmt , tab shares were up <NUM> cents , or <NUM> % , at a $ <NUM> , having earlier set a record high of a $ <NUM> . <SEP> tab shares jumped <NUM> cents , or <NUM> % , to set a record closing high at a $ <NUM>
# | tgt word:  ['around', 'tab', 'shares', 'were', '%', ',', 'of', '$', 'cents', ',', 'a', 'record', 'high', 'at', '<NUM>']
# | prd word:  ['around', 'tab', 'shares', 'were', '%', ',', 'of', '$', 'cents', ',', 'a', 'record', 'high', 'at', '<NUM>']
#
#
# step:  9600 | time: 20.52 | loss: 0.489
# | tgt:  <GO> and alabama chief justice roy moore , <MASK> installed <MASK> monument <MASK> the courthouse two years ago <MASK> <MASK> he will <MASK> to keep his job . <SEP> <MASK> was the culmination <MASK> a <MASK> <MASK> by alabama <MASK> justice roy moore , <MASK> installed <MASK> <MASK> <MASK> in the alabama judicial building <MASK> <NUM>
# | prd:  <GO> and alabama chief justice roy moore , who installed the monument in the monument two years ago , said he will fight to keep his job . <SEP> it was the monument of a row installed by alabama chief justice roy moore , who installed the 2400kg monument in the alabama judicial building in <NUM>
# | tgt word:  ['who', 'the', 'in', ',', 'said', 'fight', 'it', 'of', 'row', 'caused', 'chief', 'who', 'the', '2400kg', 'monument', 'in']
# | prd word:  ['who', 'the', 'in', ',', 'said', 'fight', 'it', 'of', 'row', 'installed', 'chief', 'who', 'the', '2400kg', 'monument', 'in']
#
#
# step:  9700 | time: 20.11 | loss: 0.078
# | tgt:  <GO> the man , fazul abdullah mohammed , a comoros islander , is on the u.s. fbi 's list of most wanted suspects . <SEP> a comoros islander , he is on the united states ' list of most wanted suspects
# | prd:  <GO> the man , fazul abdullah mohammed , a comoros islander , is on the u.s. fbi 's list of most wanted suspects . <SEP> a comoros islander , he is on the united states ' list of most wanted suspects
# | tgt word:  [',', 'a', 'islander', "'s", 'wanted', 'suspects', 'islander', 'he', 'the', 'list', 'of', 'suspects']
# | prd word:  [',', 'a', 'islander', "'s", 'wanted', 'suspects', 'islander', 'he', 'the', 'list', 'of', 'suspects']
#
#
# step:  9800 | time: 19.93 | loss: 0.096
# | tgt:  <GO> tibco has used the rendezvous name since <NUM> for several of its technology products , according to the palo alto , california company . <SEP> tibco has used the rendezvous name since <NUM> for several of its technology products , it said
# | prd:  <GO> tibco has used the rendezvous name since <NUM> for several of its technology products , according to the palo alto , california company . <SEP> tibco has used the rendezvous name since <NUM> for several of its technology products , it said
# | tgt word:  ['name', '<NUM>', 'several', ',', 'to', 'the', 'alto', 'california', 'rendezvous', 'name', 'products', 'it']
# | prd word:  ['name', '<NUM>', 'several', ',', 'to', 'the', 'alto', 'california', 'rendezvous', 'name', 'products', 'it']
#
#
# step:  9900 | time: 20.08 | loss: 0.500
# | tgt:  <MASK> <MASK> <MASK> former <MASK> accounting officer , <MASK> korkuc , <MASK> expected <MASK> plead guilty in a <MASK> court in long island <MASK> thursday , according <MASK> reports . <SEP> the <MASK> and exchange commission <MASK> that <MASK> korkuc was expected to plead guilty thursday <MASK> federal court <MASK> long island to securities <MASK> charges
# | prd:  <GO> symbol 's former chief accounting officer , robert korkuc , is expected to plead guilty in a federal court in long island later thursday , according to reports . <SEP> the securities and exchange commission announced that robert korkuc was expected to plead guilty thursday in federal court on long island to securities fraud charges
# | tgt word:  ['<GO>', 'symbol', "'s", 'chief', 'robert', 'is', 'to', 'federal', 'later', 'to', 'securities', 'announced', 'robert', 'in', 'on', 'fraud']
# | prd word:  ['<GO>', 'symbol', "'s", 'chief', 'robert', 'is', 'to', 'federal', 'later', 'to', 'securities', 'announced', 'robert', 'in', 'on', 'fraud']

# %% [markdown]
# 1 Physical GPUs, 1 Logical GPUs
#
# num word:  12880
#
#
# step:  0 | time: 5.87 | loss: 9.641
#
# | tgt:  <GO> hundreds of reporters and photographers swamped the courthouse <MASK> <MASK> the hearing <MASK> <MASK> was carried live on <MASK> cable networks . <SEP> hundreds of reporters <MASK> <MASK> <MASK> <MASK> town <MASK> the <MASK> hearing involving the five-time <MASK> was carried live on <MASK> cable networks
#
# | prd:  ophir sunnis murrah sunnis elf smooth sisters -ton sunnis davidowitz contested sunnis arab foreign-exchange grave sunnis sunnis licence contested elf murrah elf elf elf elf sunnis medicaid intensities elf distributed intensities elusive caufield licence ships--about xl davidowitz licence sisters elf .rlx broadside ships--about sunnis davidowitz sunnis elf
#
# | tgt word:  ['grounds', 'before', ',', 'which', 'national', 'and', 'photographers', 'swamped', 'the', 'and', 'short', 'all-star', 'national']
#
# | prd word:  ['davidowitz', 'contested', 'foreign-exchange', 'grave', 'elf', 'intensities', 'elf', 'distributed', 'intensities', 'caufield', 'ships--about', 'elf', 'davidowitz']
#
#
#
#
# step:  9900 | time: 20.08 | loss: 0.500
#
# | tgt:  <MASK> <MASK> <MASK> former <MASK> accounting officer , <MASK> korkuc , <MASK> expected <MASK> plead guilty in a <MASK> court in long island <MASK> thursday , according <MASK> reports . <SEP> the <MASK> and exchange commission <MASK> that <MASK> korkuc was expected to plead guilty thursday <MASK> federal court <MASK> long island to securities <MASK> charges
#
# | prd:  <GO> symbol 's former chief accounting officer , robert korkuc , is expected to plead guilty in a federal court in long island later thursday , according to reports . <SEP> the securities and exchange commission announced that robert korkuc was expected to plead guilty thursday in federal court on long island to securities fraud charges
#
# | tgt word:  ['<GO>', 'symbol', "'s", 'chief', 'robert', 'is', 'to', 'federal', 'later', 'to', 'securities', 'announced', 'robert', 'in', 'on', 'fraud']
#
# | prd word:  ['<GO>', 'symbol', "'s", 'chief', 'robert', 'is', 'to', 'federal', 'later', 'to', 'securities', 'announced', 'robert', 'in', 'on', 'fraud']
